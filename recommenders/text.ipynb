# %%
# Script dependencies
import pandas as pd
import numpy as np

# %%
# Importing data
movies_df = pd.read_csv('../resources/data/movies.csv')
ratings_df = pd.read_csv('../resources/data/ratings.csv')
media_df =  pd.read_csv('../resources/data/links_with_media.csv')

# %%
ratings = ratings_df.merge(movies_df, on='movieId', how='left')
updated_ratings = ratings.drop_duplicates(subset=['movieId'])
updated_ratings
# Out:
#        userId  movieId  rating   timestamp  \
# 0           1       31     2.5  1260759144
# 1           1     1029     3.0  1260759179
# 2           1     1061     3.0  1260759182
# 3           1     1129     2.0  1260759185
# 4           1     1172     4.0  1260759205
# ...       ...      ...     ...         ...
# 99131     664    64997     2.5  1343761859
# 99159     664    72380     3.5  1344435977
# 99274     665      129     3.0   995232528
# 99678     665     4736     1.0  1010197684
# 99820     668     6425     1.0   993613478
#
#                                                 title  \
# 0                              Dangerous Minds (1995)
# 1                                        Dumbo (1941)
# 2                                     Sleepers (1996)
# 3                         Escape from New York (1981)
# 4      Cinema Paradiso (Nuovo cinema Paradiso) (1989)
# ...                                               ...
# 99131                        War of the Worlds (2005)
# 99159                                 Box, The (2009)
# 99274                           Pie in the Sky (1996)
# 99678                             Summer Catch (2001)
# 99820            6th Man, The (Sixth Man, The) (1997)
#
#                                      genres
# 0                                     Drama
# 1          Animation|Children|Drama|Musical
# 2                                  Thriller
# 3          Action|Adventure|Sci-Fi|Thriller
# 4                                     Drama
# ...                                     ...
# 99131                         Action|Sci-Fi
# 99159  Drama|Horror|Mystery|Sci-Fi|Thriller
# 99274                        Comedy|Romance
# 99678                  Comedy|Drama|Romance
# 99820                                Comedy
#
# [9066 rows x 6 columns]

# %%
newMovie_df = updated_ratings.merge(media_df, on='movieId', )
newMovie_df = newMovie_df.drop('Unnamed: 0', axis=1)

# %%
newMovie_df
# Out:
#       userId  movieId  rating   timestamp  \
# 0          1       31     2.5  1260759144
# 1          1     1029     3.0  1260759179
# 2          1     1061     3.0  1260759182
# 3          1     1129     2.0  1260759185
# 4          1     1172     4.0  1260759205
# ...      ...      ...     ...         ...
# 8857     664    64997     2.5  1343761859
# 8858     664    72380     3.5  1344435977
# 8859     665      129     3.0   995232528
# 8860     665     4736     1.0  1010197684
# 8861     668     6425     1.0   993613478
#
#                                                title  \
# 0                             Dangerous Minds (1995)
# 1                                       Dumbo (1941)
# 2                                    Sleepers (1996)
# 3                        Escape from New York (1981)
# 4     Cinema Paradiso (Nuovo cinema Paradiso) (1989)
# ...                                              ...
# 8857                        War of the Worlds (2005)
# 8858                                 Box, The (2009)
# 8859                           Pie in the Sky (1996)
# 8860                             Summer Catch (2001)
# 8861            6th Man, The (Sixth Man, The) (1997)
#
#                                     genres  imdbId    tmdbId  \
# 0                                    Drama  112792    9909.0
# 1         Animation|Children|Drama|Musical   33563   11360.0
# 2                                 Thriller  117665     819.0
# 3         Action|Adventure|Sci-Fi|Thriller   82340    1103.0
# 4                                    Drama   95765   11216.0
# ...                                    ...     ...       ...
# 8857                         Action|Sci-Fi  449040   34812.0
# 8858  Drama|Horror|Mystery|Sci-Fi|Thriller  362478   22825.0
# 8859                        Comedy|Romance  114131  110972.0
# 8860                  Comedy|Drama|Romance  234829   26602.0
# 8861                                Comedy  120142   36807.0
#
#                                        link  \
# 0     https://www.imdb.com/title/tt0112792/
# 1     https://www.imdb.com/title/tt0033563/
# 2     https://www.imdb.com/title/tt0117665/
# 3     https://www.imdb.com/title/tt0082340/
# 4     https://www.imdb.com/title/tt0095765/
# ...                                     ...
# 8857  https://www.imdb.com/title/tt0449040/
# 8858  https://www.imdb.com/title/tt0362478/
# 8859  https://www.imdb.com/title/tt0114131/
# 8860  https://www.imdb.com/title/tt0234829/
# 8861  https://www.imdb.com/title/tt0120142/
#
#                                                  images
# 0     https://image.tmdb.org/t/p/w500//yWHWC8fJRp2kL...
# 1     https://image.tmdb.org/t/p/w500//hKDdllslMtsU9...
# 2     https://image.tmdb.org/t/p/w500//eoYdbtJOvyshB...
# 3     https://image.tmdb.org/t/p/w500//bOXk4mF2TjMJV...
# 4     https://image.tmdb.org/t/p/w500//8SRUfRUi6x4O6...
# ...                                                 ...
# 8857  https://i5.walmartimages.com/asr/4add4de6-7b92...
# 8858  https://i5.walmartimages.com/asr/4add4de6-7b92...
# 8859  https://image.tmdb.org/t/p/w500//iZs2BzP1nbrcH...
# 8860  https://i5.walmartimages.com/asr/4add4de6-7b92...
# 8861  https://i5.walmartimages.com/asr/4add4de6-7b92...
#
# [8862 rows x 10 columns]

# %%
def get_ratings_and_info():
    # Select required columns
    random_50 = []
    ratings_info = newMovie_df[['rating', 'title', 'link', 'images']].head(50)
    for index, row in ratings_info.iterrows():
        movie = {
            'title': row['title'],
            'link': row['link'],
            'images': row['images'],
            'rating': row['rating']
        }
        random_50.append(movie)
    return random_50

# %%
get_ratings_and_info()
# Out:
# [{'title': 'Dangerous Minds (1995)',
#   'link': 'https://www.imdb.com/title/tt0112792/',
#   'images': 'https://image.tmdb.org/t/p/w500//yWHWC8fJRp2kLgiFrEa8o3krOH9.jpg',
#   'rating': 2.5},
#  {'title': 'Dumbo (1941)',
#   'link': 'https://www.imdb.com/title/tt0033563/',
#   'images': 'https://image.tmdb.org/t/p/w500//hKDdllslMtsU9JixAv5HR9biXlp.jpg',
#   'rating': 3.0},
#  {'title': 'Sleepers (1996)',
#   'link': 'https://www.imdb.com/title/tt0117665/',
#   'images': 'https://image.tmdb.org/t/p/w500//eoYdbtJOvyshBgIEtsoH4uBEVR9.jpg',
#   'rating': 3.0},
#  {'title': 'Escape from New York (1981)',
#   'link': 'https://www.imdb.com/title/tt0082340/',
#   'images': 'https://image.tmdb.org/t/p/w500//bOXk4mF2TjMJVq8DZYUtblKOR92.jpg',
#   'rating': 2.0},
#  {'title': 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)',
#   'link': 'https://www.imdb.com/title/tt0095765/',
#   'images': 'https://image.tmdb.org/t/p/w500//8SRUfRUi6x4O68n0VCbDNRa6iGL.jpg',
#   'rating': 4.0},
#  {'title': 'Deer Hunter, The (1978)',
#   'link': 'https://www.imdb.com/title/tt0077416/',
#   'images': 'https://image.tmdb.org/t/p/w500//bbGtogDZOg09bm42KIpCXUXICkh.jpg',
#   'rating': 2.0},
#  {'title': 'Ben-Hur (1959)',
#   'link': 'https://www.imdb.com/title/tt0052618/',
#   'images': 'https://image.tmdb.org/t/p/w500//m4WQ1dBIrEIHZNCoAjdpxwSKWyH.jpg',
#   'rating': 2.0},
#  {'title': 'Gandhi (1982)',
#   'link': 'https://www.imdb.com/title/tt0083987/',
#   'images': 'https://image.tmdb.org/t/p/w500//rOXftt7SluxskrFrvU7qFJa5zeN.jpg',
#   'rating': 2.0},
#  {'title': "Dracula (Bram Stoker's Dracula) (1992)",
#   'link': 'https://www.imdb.com/title/tt0103874/',
#   'images': 'https://image.tmdb.org/t/p/w500//scFDS0U5uYAjcVTyjNc7GmcZw1q.jpg',
#   'rating': 3.5},
#  {'title': 'Cape Fear (1991)',
#   'link': 'https://www.imdb.com/title/tt0101540/',
#   'images': 'https://image.tmdb.org/t/p/w500//ws4mrtndzgSH5QGCamOFAgilr2R.jpg',
#   'rating': 2.0},
#  {'title': 'Star Trek: The Motion Picture (1979)',
#   'link': 'https://www.imdb.com/title/tt0079945/',
#   'images': 'https://image.tmdb.org/t/p/w500//wfiAfNwH6CMKxz4vRaW8CPTabtk.jpg',
#   'rating': 2.5},
#  {'title': 'Beavis and Butt-Head Do America (1996)',
#   'link': 'https://www.imdb.com/title/tt0115641/',
#   'images': 'https://image.tmdb.org/t/p/w500//wEB1GPT7mQcTNuYT73s72ljjbMF.jpg',
#   'rating': 1.0},
#  {'title': 'French Connection, The (1971)',
#   'link': 'https://www.imdb.com/title/tt0067116/',
#   'images': 'https://image.tmdb.org/t/p/w500//bqlcEdZN0VGBFMJuzl3HlqMLFUV.jpg',
#   'rating': 4.0},
#  {'title': 'Tron (1982)',
#   'link': 'https://www.imdb.com/title/tt0084827/',
#   'images': 'https://image.tmdb.org/t/p/w500//zwSFEczP7AzqugAHHIX3zHniT0t.jpg',
#   'rating': 4.0},
#  {'title': 'Gods Must Be Crazy, The (1980)',
#   'link': 'https://www.imdb.com/title/tt0080801/',
#   'images': 'https://image.tmdb.org/t/p/w500//IgBfj5LfT7nwpodCZ34QCHp17x.jpg',
#   'rating': 3.0},
#  {'title': 'Willow (1988)',
#   'link': 'https://www.imdb.com/title/tt0096446/',
#   'images': 'https://image.tmdb.org/t/p/w500//d9xEILdvVRX8ZgFwPDbco6kKSaS.jpg',
#   'rating': 2.0},
#  {'title': 'Antz (1998)',
#   'link': 'https://www.imdb.com/title/tt0120587/',
#   'images': 'https://image.tmdb.org/t/p/w500//lWPjxbUMpAHFkJpZHHNWhQaRsax.jpg',
#   'rating': 2.0},
#  {'title': 'Fly, The (1986)',
#   'link': 'https://www.imdb.com/title/tt0091064/',
#   'images': 'https://i5.walmartimages.com/asr/4add4de6-7b92-4846-8316-b7a0cbec4dc7_1.8e2f7305081b9284e56d112fe146dc90.png',
#   'rating': 2.5},
#  {'title': 'Time Bandits (1981)',
#   'link': 'https://www.imdb.com/title/tt0081633/',
#   'images': 'https://i5.walmartimages.com/asr/4add4de6-7b92-4846-8316-b7a0cbec4dc7_1.8e2f7305081b9284e56d112fe146dc90.png',
#   'rating': 1.0},
#  {'title': 'Blazing Saddles (1974)',
#   'link': 'https://www.imdb.com/title/tt0071230/',
#   'images': 'https://i5.walmartimages.com/asr/4add4de6-7b92-4846-8316-b7a0cbec4dc7_1.8e2f7305081b9284e56d112fe146dc90.png',
#   'rating': 3.0},
#  {'title': 'GoldenEye (1995)',
#   'link': 'https://www.imdb.com/title/tt0113189/',
#   'images': 'https://image.tmdb.org/t/p/w500//z0ljRnNxIO7CRBhLEO0DvLgAFPR.jpg',
#   'rating': 4.0},
#  {'title': 'Sense and Sensibility (1995)',
#   'link': 'https://www.imdb.com/title/tt0114388/',
#   'images': 'https://image.tmdb.org/t/p/w500//cBK2yL3HqhFvIVd7lLtazWlRZPR.jpg',
#   'rating': 5.0},
#  {'title': 'Clueless (1995)',
#   'link': 'https://www.imdb.com/title/tt0112697/',
#   'images': 'https://image.tmdb.org/t/p/w500//8AwVTcgpTnmeOs4TdTWqcFDXEsA.jpg',
#   'rating': 5.0},
#  {'title': 'Seven (a.k.a. Se7en) (1995)',
#   'link': 'https://www.imdb.com/title/tt0114369/',
#   'images': 'https://image.tmdb.org/t/p/w500//69Sns8WoET6CfaYlIkHbla4l7nC.jpg',
#   'rating': 4.0},
#  {'title': 'Usual Suspects, The (1995)',
#   'link': 'https://www.imdb.com/title/tt0114814/',
#   'images': 'https://image.tmdb.org/t/p/w500//bUPmtQzrRhzqYySeiMpv7GurAfm.jpg',
#   'rating': 4.0},
#  {'title': 'Mighty Aphrodite (1995)',
#   'link': 'https://www.imdb.com/title/tt0113819/',
#   'images': 'https://image.tmdb.org/t/p/w500//cm0oPKizOQlsXpGYvrHvpELfxdi.jpg',
#   'rating': 3.0},
#  {'title': "Mr. Holland's Opus (1995)",
#   'link': 'https://www.imdb.com/title/tt0113862/',
#   'images': 'https://image.tmdb.org/t/p/w500//kBmwWeSN3ajnYHZ3dSybEobxEPI.jpg',
#   'rating': 3.0},
#  {'title': 'Braveheart (1995)',
#   'link': 'https://www.imdb.com/title/tt0112573/',
#   'images': 'https://image.tmdb.org/t/p/w500//or1gBugydmjToAEq7OZY0owwFk.jpg',
#   'rating': 4.0},
#  {'title': 'Brothers McMullen, The (1995)',
#   'link': 'https://www.imdb.com/title/tt0112585/',
#   'images': 'https://image.tmdb.org/t/p/w500//6oWsOJP0ed5gs8n2UywcailoxFN.jpg',
#   'rating': 3.0},
#  {'title': 'Apollo 13 (1995)',
#   'link': 'https://www.imdb.com/title/tt0112384/',
#   'images': 'https://image.tmdb.org/t/p/w500//oYUZHYMwNKnE1ef4WE5Hw2a9OAY.jpg',
#   'rating': 5.0},
#  {'title': 'Batman Forever (1995)',
#   'link': 'https://www.imdb.com/title/tt0112462/',
#   'images': 'https://image.tmdb.org/t/p/w500//mzzNBVwTiiY94xAXDMWJpNPW2US.jpg',
#   'rating': 4.0},
#  {'title': 'Crimson Tide (1995)',
#   'link': 'https://www.imdb.com/title/tt0112740/',
#   'images': 'https://image.tmdb.org/t/p/w500//21nqRJ6ofEgVvEl68J4O9V26Xzy.jpg',
#   'rating': 3.0},
#  {'title': 'Die Hard: With a Vengeance (1995)',
#   'link': 'https://www.imdb.com/title/tt0112864/',
#   'images': 'https://image.tmdb.org/t/p/w500//lwTE6cUhGxRaJvQ5VPdletIGDPh.jpg',
#   'rating': 3.0},
#  {'title': 'First Knight (1995)',
#   'link': 'https://www.imdb.com/title/tt0113071/',
#   'images': 'https://image.tmdb.org/t/p/w500//xuXkCcrvUTkehVXuTGpnfySsx0Z.jpg',
#   'rating': 3.0},
#  {'title': 'Net, The (1995)',
#   'link': 'https://www.imdb.com/title/tt0113957/',
#   'images': 'https://image.tmdb.org/t/p/w500//dtupntUFMD5iXBo8HLfALt2ET4R.jpg',
#   'rating': 3.0},
#  {'title': 'Nine Months (1995)',
#   'link': 'https://www.imdb.com/title/tt0113986/',
#   'images': 'https://image.tmdb.org/t/p/w500//z1nzYuoeTbGBrSicDxJEhJhEQz8.jpg',
#   'rating': 3.0},
#  {'title': 'Waterworld (1995)',
#   'link': 'https://www.imdb.com/title/tt0114898/',
#   'images': 'https://image.tmdb.org/t/p/w500//nyCA6UfqEPsH1lqL6YVtVf0KwwN.jpg',
#   'rating': 3.0},
#  {'title': 'Circle of Friends (1995)',
#   'link': 'https://www.imdb.com/title/tt0112679/',
#   'images': 'https://image.tmdb.org/t/p/w500//dmyEriE6TsnbgkNaFOvCcXaF0Nt.jpg',
#   'rating': 5.0},
#  {'title': 'Clerks (1994)',
#   'link': 'https://www.imdb.com/title/tt0109445/',
#   'images': 'https://image.tmdb.org/t/p/w500//zeFhNF0SXlYIvWXpaOLuXVQ3jB4.jpg',
#   'rating': 1.0},
#  {'title': 'Disclosure (1994)',
#   'link': 'https://www.imdb.com/title/tt0109635/',
#   'images': 'https://image.tmdb.org/t/p/w500//1DcDAJ5vM5XKKONmTaadq5GHpfk.jpg',
#   'rating': 3.0},
#  {'title': 'Ed Wood (1994)',
#   'link': 'https://www.imdb.com/title/tt0109707/',
#   'images': 'https://image.tmdb.org/t/p/w500//ab28VMfoYOJcHipIVFmd7hYW029.jpg',
#   'rating': 3.0},
#  {'title': 'Houseguest (1994)',
#   'link': 'https://www.imdb.com/title/tt0110066/',
#   'images': 'https://image.tmdb.org/t/p/w500//cdiHlZho11EEqD3aPanYe1rEYRB.jpg',
#   'rating': 3.0},
#  {'title': 'Interview with the Vampire: The Vampire Chronicles (1994)',
#   'link': 'https://www.imdb.com/title/tt0110148/',
#   'images': 'https://image.tmdb.org/t/p/w500//2162lAT2MP36MyJd2sttmj5du5T.jpg',
#   'rating': 4.0},
#  {'title': 'Little Women (1994)',
#   'link': 'https://www.imdb.com/title/tt0110367/',
#   'images': 'https://image.tmdb.org/t/p/w500//1ZzH1XMcKAe5NdrKL5MfcqZHHsZ.jpg',
#   'rating': 4.0},
#  {'title': 'Like Water for Chocolate (Como agua para chocolate) (1992)',
#   'link': 'https://www.imdb.com/title/tt0103994/',
#   'images': 'https://image.tmdb.org/t/p/w500//itwUdMqLmPfhtGJ44hiDxkqZhiq.jpg',
#   'rating': 5.0},
#  {'title': 'Legends of the Fall (1994)',
#   'link': 'https://www.imdb.com/title/tt0110322/',
#   'images': 'https://image.tmdb.org/t/p/w500//t1KPGlW0UGd0m515LPQmk2F4nu1.jpg',
#   'rating': 5.0},
#  {'title': 'Madness of King George, The (1994)',
#   'link': 'https://www.imdb.com/title/tt0110428/',
#   'images': 'https://image.tmdb.org/t/p/w500//pnAPAcUHpUQ9v8PXZtMTnbovc7x.jpg',
#   'rating': 3.0},
#  {'title': "Mary Shelley's Frankenstein (Frankenstein) (1994)",
#   'link': 'https://www.imdb.com/title/tt0109836/',
#   'images': 'https://image.tmdb.org/t/p/w500//bOwCAQsZlEKrwhPi1ejY6BS8jpL.jpg',
#   'rating': 4.0},
#  {'title': 'Outbreak (1995)',
#   'link': 'https://www.imdb.com/title/tt0114069/',
#   'images': 'https://image.tmdb.org/t/p/w500//dxr5NoaIALZThSYeeaJKlMGCZlY.jpg',
#   'rating': 3.0},
#  {'title': 'Pulp Fiction (1994)',
#   'link': 'https://www.imdb.com/title/tt0110912/',
#   'images': 'https://image.tmdb.org/t/p/w500//fIE3lAGcZDV1G6XM5KmuWnNsPp1.jpg',
#   'rating': 4.0}]
